# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv(r'C:\Users\Abc\Desktop\dataset.csv')
df.head()
# Out:
#    Unnamed: 0     Area    Perimeter  Convex Area  Solidity  \
# 0           0   6314.5   521.972649       9855.5  0.640708
# 1           1  52776.5  1189.820409      59947.0  0.880386
# 2           2  50232.5  1415.349410      69628.5  0.721436
# 3           3   4486.0   275.622365       4741.5  0.946114
# 4           4    145.0    92.083260        323.5  0.448223
#
#    Equivalent Diameter  Major Axis  Minor Axis  \
# 0            89.665328   86.297539  146.952896
# 1           259.224086  209.590240  405.861420
# 2           252.899200  223.632736  373.077637
# 3            75.576138   64.818382   93.083397
# 4            13.587484   16.900970   28.915043
#
#                                   Eccentricity  Class
# 0  (8.439724311699382e-17+1.3783115780934465j)      1
# 1  (1.015395044877726e-16+1.6582659515946696j)      1
# 2  (8.176507178841775e-17+1.3353249581078526j)      1
# 3  (6.311037889163952e-17+1.0306707033502136j)      1
# ...

# %%
    df.shape
# Out:
# (241, 10)

# %%
df.describe()
# Out:
#        Unnamed: 0          Area    Perimeter   Convex Area    Solidity  \
# count  241.000000  2.410000e+02   241.000000  2.410000e+02  241.000000
# mean   120.000000  1.284881e+04   467.813734  2.335118e+04    0.532210
# std     69.714896  8.028041e+04   695.350981  8.992601e+04    0.356740
# min      0.000000  0.000000e+00     0.000000  0.000000e+00    0.000000
# 25%     60.000000  9.700000e+01    63.112697  1.375000e+02    0.129455
# 50%    120.000000  8.275000e+02   205.338093  1.456500e+03    0.624549
# 75%    180.000000  3.996000e+03   553.931020  9.377000e+03    0.875000
# max    240.000000  1.164150e+06  4453.521314  1.172680e+06    0.997361
#
#        Equivalent Diameter   Major Axis    Minor Axis       Class
# count           241.000000   241.000000    241.000000  241.000000
# mean             63.181604   112.305093    213.697689    0.618257
# std             111.441582   203.992757    904.717765    0.486825
# ...

# %%
df.isnull()
# Out:
#      Unnamed: 0   Area  Perimeter  Convex Area  Solidity  Equivalent Diameter  \
# 0         False  False      False        False     False                False
# 1         False  False      False        False     False                False
# 2         False  False      False        False     False                False
# 3         False  False      False        False     False                False
# 4         False  False      False        False     False                False
# ..          ...    ...        ...          ...       ...                  ...
# 236       False  False      False        False     False                False
# 237       False  False      False        False     False                False
# 238       False  False      False        False     False                False
# 239       False  False      False        False     False                False
# 240       False  False      False        False     False                False
#
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0               int64
# Area                   float64
# Perimeter              float64
# Convex Area            float64
# Solidity               float64
# Equivalent Diameter    float64
# Major Axis             float64
# Minor Axis             float64
# Eccentricity            object
# Class                    int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Unnamed: 0             0
# Area                   0
# Perimeter              0
# Convex Area            0
# Solidity               0
# Equivalent Diameter    0
# Major Axis             0
# Minor Axis             0
# Eccentricity           0
# Class                  0
# dtype: int64

# %%
df.corr()
# Out:
#                      Unnamed: 0      Area  Perimeter  Convex Area  Solidity  \
# Unnamed: 0             1.000000 -0.084951  -0.205686    -0.095241 -0.271263
# Area                  -0.084951  1.000000   0.507090     0.906965  0.150100
# Perimeter             -0.205686  0.507090   1.000000     0.751252 -0.131954
# Convex Area           -0.095241  0.906965   0.751252     1.000000  0.013181
# Solidity              -0.271263  0.150100  -0.131954     0.013181  1.000000
# Equivalent Diameter   -0.248822  0.863930   0.727837     0.850233  0.241274
# Major Axis            -0.110768  0.402509   0.670185     0.548482 -0.185935
# Minor Axis            -0.033407  0.103028   0.201981     0.141966 -0.108843
# Class                 -0.841462  0.108898   0.249779     0.143266  0.304830
#
#                      Equivalent Diameter  Major Axis  Minor Axis     Class
# Unnamed: 0                     -0.248822   -0.110768   -0.033407 -0.841462
# ...

# %%
import seaborn as sns
import matplotlib  as  plt

# %%
sns.heatmap(df.corr())

# %%
sns_plot=sns.pairplot(df)
sns_plot.savefig("output.png")

# %%
df.drop(['Unnamed: 0','Eccentricity'],axis=1,inplace=True)

# %%
df.head()
# Out:
#       Area    Perimeter  Convex Area  Solidity  Equivalent Diameter  \
# 0   6314.5   521.972649       9855.5  0.640708            89.665328
# 1  52776.5  1189.820409      59947.0  0.880386           259.224086
# 2  50232.5  1415.349410      69628.5  0.721436           252.899200
# 3   4486.0   275.622365       4741.5  0.946114            75.576138
# 4    145.0    92.083260        323.5  0.448223            13.587484
#
#    Major Axis  Minor Axis  Class
# 0   86.297539  146.952896      1
# 1  209.590240  405.861420      1
# 2  223.632736  373.077637      1
# 3   64.818382   93.083397      1
# 4   16.900970   28.915043      1

# %%
df
# Out:
#         Area    Perimeter  Convex Area  Solidity  Equivalent Diameter  \
# 0     6314.5   521.972649       9855.5  0.640708            89.665328
# 1    52776.5  1189.820409      59947.0  0.880386           259.224086
# 2    50232.5  1415.349410      69628.5  0.721436           252.899200
# 3     4486.0   275.622365       4741.5  0.946114            75.576138
# 4      145.0    92.083260        323.5  0.448223            13.587484
# ..       ...          ...          ...       ...                  ...
# 236    545.5   208.267025       1317.5  0.414042            26.354358
# 237    902.0   232.166520       1444.5  0.624438            33.888967
# 238   3177.0   217.681239       3260.0  0.974540            63.600959
# 239   6103.0  1208.631593      51259.5  0.119061            88.150899
# 240    250.0    66.769552        264.0  0.946970            17.841241
#
#      Major Axis  Minor Axis  Class
# 0     86.297539  146.952896      1
# 1    209.590240  405.861420      1
# ...

# %%
X=df.iloc[:,:7]

X.head()
# Out:
#       Area    Perimeter  Convex Area  Solidity  Equivalent Diameter  \
# 0   6314.5   521.972649       9855.5  0.640708            89.665328
# 1  52776.5  1189.820409      59947.0  0.880386           259.224086
# 2  50232.5  1415.349410      69628.5  0.721436           252.899200
# 3   4486.0   275.622365       4741.5  0.946114            75.576138
# 4    145.0    92.083260        323.5  0.448223            13.587484
#
#    Major Axis  Minor Axis
# 0   86.297539  146.952896
# 1  209.590240  405.861420
# 2  223.632736  373.077637
# 3   64.818382   93.083397
# 4   16.900970   28.915043

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaling=StandardScaler()

# %%
X = scaling.fit_transform(X)
X
# Out:
# array([[-0.08156293,  0.07804926, -0.15038767, ...,  0.23814128,
#         -0.12775787, -0.0739277 ],
#        [ 0.49838793,  1.04049511,  0.40780175, ...,  1.76281129,
#          0.47789743,  0.2128439 ],
#        [ 0.46663305,  1.36550847,  0.51568654, ...,  1.70593801,
#          0.5468789 ,  0.17653201],
#        ...,
#        [-0.12072603, -0.36046985, -0.22388393, ...,  0.00377083,
#         -0.23970679, -0.16332544],
#        [-0.08420293,  1.0676042 ,  0.3109935 , ...,  0.22452355,
#          0.82377405,  0.08001032],
#        [-0.15726161, -0.57795104, -0.25726955, ..., -0.40769992,
#         -0.48814885, -0.20754329]])

# %%
y=df.iloc[:,-1]

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Class, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=2)

# %% [markdown]
# # LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression
lg= LogisticRegression()

# %%
lg.fit(X_train,y_train)
# Out:
# C:\Users\Abc\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred=lg.predict(X_test)

# %%
from sklearn import metrics
print("The accuracy of the model is: {} ".format(metrics.accuracy_score(y_pred,y_test)))
# Out:
# The accuracy of the model is: 0.726027397260274

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.40      0.55        30
#            1       0.69      0.95      0.80        43
#
#     accuracy                           0.73        73
#    macro avg       0.78      0.68      0.67        73
# weighted avg       0.76      0.73      0.70        73
#
# [[12 18]
#  [ 2 41]]

# %%
from sklearn.metrics import accuracy_score
score=accuracy_score(y_pred,y_test)
print(score)
# Out:
# 0.726027397260274

# %% [markdown]
# ## Predicting with new values

# %%
new=np.array([[-23.11,-632,-1142,-6.21,-1.67,9.665,-1.6654],[-2.871,-3.32,-11.42,-9.21,-7.67,5.665,-2.6654]])

# %%
y_pd=lg.predict(new)
y_pd
# Out:
# array([1, 0], dtype=int64)
